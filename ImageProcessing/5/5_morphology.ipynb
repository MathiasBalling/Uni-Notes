# %% [markdown]
# ## Introduction to Image Processing with Python
# ### Image Processing (RM1-VIS)
# ### University of Southern Denmark

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from random import randint

# %%
def plotImage(image, title):
    if(len(image.shape) == 2):
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Implement the morphological operations: erosion, dilation, opening and closing.

# %%
def morphology(image, operation, strel):
    imgOut = np.zeros(image.shape)

    return imgOut

# %%
binary_image = skimage.io.imread('images/fingerprint-noisy.png')
plotImage(binary_image, "fingerprint-noisy.png")

# %%
size = 3
strelBox = np.ones((size,size))

eroded_image = morphology(binary_image, 'erosion', strelBox)
plotImage(eroded_image, "erosion")

# %%
dilated_image = morphology(binary_image, 'dilation', strelBox)
plotImage(dilated_image, "dilation")

# %%
opened_image = morphology(binary_image, 'opening', strelBox)
plotImage(opened_image, "opened")

# %%
closed_image = morphology(binary_image, 'closing', strelBox)
plotImage(closed_image, "closed")

# %% [markdown]
# Implement boundary extraction

# %%
def boundary_extraction(binaryImg, strel):
    return binaryImg

# %%
img_lincoln = skimage.io.imread('images/lincoln.png')
plotImage(img_lincoln, "lincoln")

# %%
size = 5
strel = np.ones((size,size))
boundary = boundary_extraction(img_lincoln, strel)

plotImage(boundary, "boundary - lincoln")

# %% [markdown]
# Implement hole filling, connected component extraction.

# %%
img_holes = skimage.io.imread('images/balls-with-reflections.tif')
plotImage(img_holes, "img_holes")

# %%
def fill_holes(binaryImg, holes, strel):
    return binaryImg

# %% [markdown]
# Implement connected compenent labeling.
#
# Determine how many bones/foreign objects are found in the image. First threshold at intensity level 210. Then remove very small components by erosion. Lastly identify connected compoenents and determine their sizes.

# %%
img_xray = skimage.io.imread('images/chickenXray.tif')
plotImage(img_xray, "chickenXray")

# %%
# returns an image of type uint8 with the connected components of binaryImg assign unique cc values
def connected_components(binaryImg, strel, maxNumber = 20):
    
    return ccImg
