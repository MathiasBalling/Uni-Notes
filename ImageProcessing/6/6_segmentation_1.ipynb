# %% [markdown]
# ## Introduction to Image Processing with Python
# ### Image Processing (RM1-VIS)
# ### University of Southern Denmark

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from random import randint

# %%
def plotImage(image, title):
    if(len(image.shape) == 2):
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Implement Canny's edge detection algorithms.
# Tip: start with only thresholding the gradient magnitude. Then implement NMS and hystersis thresholding.

# %%
def canny(image, sigma, lowThreshold, highThreshold):
    edges = image
    return edges

# %%
image = skimage.io.imread('images/building-600by600.png')
plotImage(image, "building-600by600.png")       
edges = canny(image, 3, 10, 100)

# %% [markdown]
# Implement the Hough Transform to find vertical/horizontal lines in the output of Canny's algorithm.

# %%
plotImage(edges, "Canny edges")

# %%
def HoughLines(edgeImg, nThetas, nRhos):
    return lines

# %%
lines = HoughLines(edges, 100, 100)

plt.imshow(image)
plt.title("Hough Lines on Image")
plt.axis('off')
for l in lines:
    x = range(0, image.shape[1])
    #...
plt.show()

# %% [markdown]
# Implement Otsu's thresholding algorithm.

# %%
def otsu(img):

    return img

# %%
image = skimage.io.imread('images/fingerprint.tif')
plotImage(image, "fingerprint.tif")       
binaryImg = otsu(image)
plotImage(binaryImg, "binaryImg")
