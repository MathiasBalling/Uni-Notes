# %% [markdown]
# ## Introduction to Image Processing with Python
# ### Image Processing (RM1-VIS)
# ### University of Southern Denmark

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from random import randint

# %%
def plotImage(image, title):
    if(len(image.shape) == 2):
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### 1. Implement graph cut segmentation
#  * Use with two regions (K=2)
#  * Use the "realistic" weight metric from Example 10.24.
#  * A little pre-smoothing may be necessary.
#  * You can compare your result to Fig. 10.56.
#  * Note: scipy.linalg.eig() can solve the generalized eigenvalue problem, which might be easier than reformulating for a normal eigenvalue problem.

# %%
def graphcut(image, K, sigma_I, sigma_d):
    segmentation = image
    return segmentation

# %%
image = skimage.io.imread('images/building-600by600.png')
plotImage(image, "building-600by600.png")       
segmentation = graphcut(image, 2)

# %%
plotImage(segmentation, "Graph Cut segmentation")

# %% [markdown]
# ### 2. Implement the watershed algorithm
#  * An over-segmentation is not expected with the low-detail image.
#  * Markers are not necessary.
#  * Follow the procedure outlined on page 792 and 793.

# %%
def watershed_lines(img):

    return img

# %%
image = skimage.io.imread('images/yeast-cells.tif')
plotImage(image, "yeast-cells")       
wl = watershed_lines(image)

# %%
plotImage(wl, "Watershed segmentation")
